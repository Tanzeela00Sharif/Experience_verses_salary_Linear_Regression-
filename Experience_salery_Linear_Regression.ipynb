# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanzeela00Sharif/Experience_verses_salary_Linear_Regression-/blob/main/Experience_salery_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #importing data

# %%
data=pd.read_csv("/content/experience_salary_100.csv")
data.head()
# Out:
#    experience  salary
# 0         7.5   59185
# 1        19.0  109005
# 2        14.6   91159
# 3        12.0   69062
# 4         3.1   37852

# %% [markdown]
# #plot the data in graph

# %%
plt.scatter(data['experience'],data['salary'])
plt.title('Experience verses salery')
plt.xlabel('Experience')
plt.ylabel('Salery')
# Out:
# Text(0, 0.5, 'Salery')

# %%
print(data.columns)
print(type(data['experience']))
print(type(data['salary']))
# Out:
# Index(['experience', 'salary'], dtype='object')
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
X=data[['experience']]
Y=data[['salary']]

# %%
type(Y)
# Out:
# pandas.core.frame.DataFrame

# %%
Y
# Out:
#     salary
# 0    59185
# 1   109005
# 2    91159
# 3    69062
# 4    37852
# ..     ...
# 95   65471
# 96   71864
# 97   65406
# 98   28633
# 99   39036
#
# [100 rows x 1 columns]

# %%
data=pd.DataFrame(data)
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ##import model and split data

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y, test_size=0.2, random_state=2)

# %%
type(x_test)
# Out:
# pandas.core.frame.DataFrame

# %%
model=LinearRegression()

# %%
x_train.shape
# Out:
# (80, 1)

# %%
y_train.shape
# Out:
# (80, 1)

# %% [markdown]
# #model training

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#     experience
# 83         1.3
# 30        12.2
# 56         1.8
# 24         9.1
# 16         6.1
# 23         7.3
# 2         14.6
# 27        10.3
# 28        11.8
# 13         4.2
# 99         2.2
# 92        15.2
# 76        15.4
# 14         3.6
# 0          7.5
# 21         2.8
# 3         12.0
# 29         0.9
# 61         5.4
# 79         2.3

# %%
y_test
# Out:
#     salary
# 83   34133
# 30   89331
# 56   27788
# 24   58873
# 16   48940
# 23   56677
# 2    91159
# 27   67339
# 28   77294
# 13   46466
# 99   39036
# 92   92173
# 76   90900
# 14   41685
# 0    59185
# 21   38905
# 3    69062
# 29   31070
# 61   47690
# 79   31778

# %% [markdown]
# ##check the model prediction

# %%
model.predict([[11.2]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[75451.9348552]])

# %%
model.predict([[5.4]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[50082.35948377]])

# %% [markdown]
# ###cross check between predicted salery and calculated salery through formula

# %%
#intercept
b= model.intercept_
# Out:
# array([26462.41000002])

# %%
##slop
m= model.coef_
m
# Out:
# array([[4374.06471921]])

# %%
#y=mx +b
4374.06471921 * 5.4 +26462.41000002
# Out:
# 50082.359483754

# %%
print(f" Calculate: {4374.06471921 * 2.3 +26462.41000002}")

print(f"Predicted: {model.predict([[2.3]])}")
# Out:
#  Calculate: 36522.758854203
# Predicted: [[36522.75885421]]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
